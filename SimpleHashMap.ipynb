# %% [markdown]
# <a href="https://colab.research.google.com/github/BergProfJ/HashTestDemo/blob/main/SimpleHashMap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CPS 311 - Fall, 2026
# ## Hashing Exercises
#
# Consider the (incomplete) Python `SimpleHashMap` class below

# %%
class SimpleHashMap:
    def __init__(self, size=7):
        self.size = size
        # Create a list of empty "buckets" (lists within a list)
        self.table = [[] for _ in range(size)]

    def _hash(self, key):
        # A lightweight polynomial hash
        h = 0
        for char in str(key):
            h = h * 31 + ord(char)
        return h % self.size

    def insert(self, key, value):
        # EXERCISE:
        # 1. Compute the index using self._hash(key)
        # 2. Check if the key already exists in self.table[index] and update it
        # 3. If it doesn't exist, append the tuple (key, value) to the bucket
        pass

    def get(self, key):
        # EXERCISE:
        # 1. Compute the index using self._hash(key)
        # 2. Search the bucket at self.table[index] for the key and return its value
        # 3. Return None if not found
        pass

  def main():
    print("Hello, world!")
